# %% [markdown]
# # Smart Last-Mile Delivery Intelligence
# Week 1 Internship Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('ecommerce_last_mile.csv')
df.head()

# %% [markdown]
# ## Data Quality Checks

# %%
df.info()
df.isnull().sum()

# %% [markdown]
# ## KPI Calculation

# %%
df['Delayed']=(df['Delay_Minutes']>0).astype(int)
on_time_rate=(df['Delayed']==0).mean()*100
print(on_time_rate)
